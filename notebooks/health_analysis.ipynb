# %%
# from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
health_indicators = pd.read_csv('..\data\\analytic_data2020.csv', 
                               usecols=['State FIPS Code',
                                        'County FIPS Code',
                                        '5-digit FIPS Code',
                                        'State Abbreviation',
                                        'Name',
                                        'Population raw value',
                                        'Life expectancy raw value',
                                        'Drug overdose deaths raw value',
                                        'Median household income raw value',
                                        'Excessive drinking raw value',
                                        'Alcohol-impaired driving deaths raw value',
                                        'Income inequality raw value',
                                        'Violent crime raw value',
#                                         'Motor vehicle crash deaths raw value',
                                        'Insufficient sleep raw value',
#                                         'Residential segregation - Black/White numerator',
                                        'Suicides raw value'
                                        
#                                         'Drug overdose deaths raw value',
#                                         'Population raw value',
#                                         'Median household income raw value',
#                                         'Excessive drinking raw value',
#                                         'Alcohol-impaired driving deaths raw value',
#                                         'Alcohol-related hospitalizations raw value',
#                                         'Income inequality raw value',
#                                         'Violent crime raw value',
#                                         'Drinking water violations raw value',
#                                         'Motor vehicle crash deaths raw value',
#                                         'Insufficient sleep raw value',
#                                         'Median household income raw value',
#                                         'Residential segregation - Black/White raw value',
#                                         'Suicides raw value',
#                                         'Male population 0-17 raw value',
#                                         'Male population 18-44 raw value',
#                                         'Male population 45-64 raw value',
#                                         'Male population 65+ raw value',
#                                         'Female population 0-17 raw value',
#                                         'Female population 18-44 raw value',
#                                         'Female population 45-64 raw value',
#                                         'Female population 65+ raw value'
                                       ],
                               skiprows=[1])

# %%
us_country = gpd.read_file('../data/gz_2010_us_040_00_5m.json')

# %%
health_indicators.rename(columns={'Name': 'County'}, inplace=True)

# %%
region_division = pd.read_csv('..\data\\region_division.csv',
                             usecols=['REGION','DIVISION', 'NAME'])

# %%
health_indicators.columns = health_indicators.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
region_division.columns = region_division.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
region_map = {
    '1': 'Northeast',
    '2': 'Midwest',
    '3': 'South',
    '4': 'West',
    'X': 'Undefined'
}

# %%
division_map = {
    '1': 'New England',
    '2': 'Middle Atlantic',
    '3': 'East North Central',
    '4': 'West North Central',
    '5': 'South Atlantic',
    '6': 'East South Central',
    '7': 'West South Central',
    '8': 'Mountain',
    '9': 'Pacific',
    'X': 'Undefined'
}

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'US': 'United States',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
# Create state column so all counties are mapped with full state name
health_indicators['state'] = health_indicators.state_abbreviation.map(states)

# %%
# merge both df so region and division are added
health_final = pd.merge(health_indicators, region_division, left_on='state', right_on='name')

# %%
# map the regions so numbers are the name of the region
health_final['region'] = health_final.region.map(region_map)

# %%
# map the divisions so numbers are the name of the divsions
health_final['division'] = health_final.division.map(division_map)

# %%
health_final = health_final.drop(['name'], axis = 1)

# %%
health_final[health_final['state'] == 'Georgia']
# Out:
#      state_fips_code  county_fips_code  5-digit_fips_code state_abbreviation  \
# 398               13                 0              13000                 GA
# 399               13                 1              13001                 GA
# 400               13                 3              13003                 GA
# 401               13                 5              13005                 GA
# 402               13                 7              13007                 GA
# ..               ...               ...                ...                ...
# 553               13               313              13313                 GA
# 554               13               315              13315                 GA
# 555               13               317              13317                 GA
# 556               13               319              13319                 GA
# 557               13               321              13321                 GA
#
#                county  excessive_drinking_raw_value  \
# 398           Georgia                      0.143964
# 399    Appling County                      0.143102
# 400   Atkinson County                      0.139494
# 401      Bacon County                      0.151329
# 402      Baker County                      0.131609
# ..                ...                           ...
# 553  Whitfield County                      0.147634
# 554     Wilcox County                      0.153306
# 555     Wilkes County                      0.126557
# 556  Wilkinson County                      0.134058
# 557      Worth County                      0.144984
#
#      alcohol-impaired_driving_deaths_raw_value  income_inequality_raw_value  \
# 398                                   0.215120                     4.923855
# 399                                   0.275862                     4.760185
# 400                                   0.272727                     4.360288
# 401                                   0.222222                     5.175497
# 402                                   0.600000                     5.813483
# ..                                         ...                          ...
# 553                                   0.159420                     4.098933
# 554                                   0.000000                     5.069171
# 555                                   0.166667                     4.885482
# 556                                   0.095238                     5.406573
# 557                                   0.157895                     4.142871
#
#      violent_crime_raw_value  life_expectancy_raw_value  \
# 398               387.534831                  77.769078
# 399               379.198267                  75.209437
# 400                      NaN                  73.972711
# 401                      NaN                  73.169692
# 402                      NaN                  77.457132
# ..                       ...                        ...
# 553               263.381644                  78.228829
# 554               257.639305                  75.837066
# 555               308.071473                  75.549521
# 556               179.280318                  74.607372
# 557               419.121521                  75.369654
#
#      drug_overdose_deaths_raw_value  insufficient_sleep_raw_value  \
# 398                       13.867906                      0.362584
# 399                             NaN                      0.360408
# 400                             NaN                      0.383920
# 401                             NaN                      0.364342
# 402                             NaN                      0.375605
# ..                              ...                           ...
# 553                       12.128601                      0.380205
# 554                             NaN                      0.381932
# 555                             NaN                      0.384542
# 556                             NaN                      0.377009
# 557                       16.239039                      0.364194
#
#      median_household_income_raw_value  suicides_raw_value  \
# 398                            58634.0           13.357702
# 399                            42781.0           18.495678
# 400                            36779.0                 NaN
# 401                            38775.0                 NaN
# 402                            38288.0                 NaN
# ..                                 ...                 ...
# 553                            47074.0           12.858163
# 554                            35961.0           22.509938
# 555                            39361.0           20.922824
# 556                            41036.0                 NaN
# 557                            48708.0           18.146270
#
#      population_raw_value    state region        division
# 398              10519475  Georgia  South  South Atlantic
# 399                 18507  Georgia  South  South Atlantic
# 400                  8297  Georgia  South  South Atlantic
# 401                 11185  Georgia  South  South Atlantic
# 402                  3092  Georgia  South  South Atlantic
# ..                    ...      ...    ...             ...
# 553                104062  Georgia  South  South Atlantic
# 554                  8812  Georgia  South  South Atlantic
# 555                  9876  Georgia  South  South Atlantic
# 556                  9036  Georgia  South  South Atlantic
# 557                 20299  Georgia  South  South Atlantic
#
# [160 rows x 18 columns]

# %%
# # Plotting to see the hurricane overlay the US map:
# fig, ax = plt.subplots(1, figsize=(30,20))
# base = us_country.plot(ax=ax, column = 'STATE', cmap='Dark2')
# plt.xlim(-125, -65)
# plt.ylim(25, 50)
# plt.title('Brewery Locations: US (Excluding Hawaii and Alaska)', loc='center', fontsize=40)
# plt.xlabel('Longitude', fontsize = 25)
# plt.ylabel('Latitude', fontsize = 25)
# # plotting locations over states
# geo_locations.plot(ax=base, column=geo_locations.locality, marker="*", legend=False, cmap='jet')

# %%
health_final.columns
# Out:
# Index(['state_fips_code', 'county_fips_code', '5-digit_fips_code',
#        'state_abbreviation', 'county', 'excessive_drinking_raw_value',
#        'alcohol-impaired_driving_deaths_raw_value',
#        'income_inequality_raw_value', 'violent_crime_raw_value',
#        'life_expectancy_raw_value', 'drug_overdose_deaths_raw_value',
#        'insufficient_sleep_raw_value', 'median_household_income_raw_value',
#        'suicides_raw_value', 'population_raw_value', 'state', 'region',
#        'division'],
#       dtype='object')

# %%
health_final.to_csv("../data/health_final.csv", encoding='utf-8', index = False)

# %%
# health_final[health_final['5-digit_fips_code'] == '033']

# %%
health_indicators.tail(50)
# Out:
#       state_fips_code  county_fips_code  5-digit_fips_code state_abbreviation  \
# 3144               55                91              55091                 WI
# 3145               55                93              55093                 WI
# 3146               55                95              55095                 WI
# 3147               55                97              55097                 WI
# 3148               55                99              55099                 WI
# 3149               55               101              55101                 WI
# 3150               55               103              55103                 WI
# 3151               55               105              55105                 WI
# 3152               55               107              55107                 WI
# 3153               55               109              55109                 WI
# 3154               55               111              55111                 WI
# 3155               55               113              55113                 WI
# 3156               55               115              55115                 WI
# 3157               55               117              55117                 WI
# 3158               55               119              55119                 WI
# 3159               55               121              55121                 WI
# 3160               55               123              55123                 WI
# 3161               55               125              55125                 WI
# 3162               55               127              55127                 WI
# 3163               55               129              55129                 WI
# 3164               55               131              55131                 WI
# 3165               55               133              55133                 WI
# 3166               55               135              55135                 WI
# 3167               55               137              55137                 WI
# 3168               55               139              55139                 WI
# 3169               55               141              55141                 WI
# 3170               56                 0              56000                 WY
# 3171               56                 1              56001                 WY
# 3172               56                 3              56003                 WY
# 3173               56                 5              56005                 WY
# 3174               56                 7              56007                 WY
# 3175               56                 9              56009                 WY
# 3176               56                11              56011                 WY
# 3177               56                13              56013                 WY
# 3178               56                15              56015                 WY
# 3179               56                17              56017                 WY
# 3180               56                19              56019                 WY
# 3181               56                21              56021                 WY
# 3182               56                23              56023                 WY
# 3183               56                25              56025                 WY
# 3184               56                27              56027                 WY
# 3185               56                29              56029                 WY
# 3186               56                31              56031                 WY
# 3187               56                33              56033                 WY
# 3188               56                35              56035                 WY
# 3189               56                37              56037                 WY
# 3190               56                39              56039                 WY
# 3191               56                41              56041                 WY
# 3192               56                43              56043                 WY
# 3193               56                45              56045                 WY
#
#                   county  excessive_drinking_raw_value  \
# 3144        Pepin County                      0.239325
# 3145       Pierce County                      0.286237
# 3146         Polk County                      0.240197
# 3147      Portage County                      0.273238
# 3148        Price County                      0.220260
# 3149       Racine County                      0.256689
# 3150     Richland County                      0.229738
# 3151         Rock County                      0.232382
# 3152         Rusk County                      0.225479
# 3153    St. Croix County                      0.279606
# 3154         Sauk County                      0.259689
# 3155       Sawyer County                      0.224497
# 3156      Shawano County                      0.232790
# 3157    Sheboygan County                      0.272795
# 3158       Taylor County                      0.250658
# 3159  Trempealeau County                      0.263408
# 3160       Vernon County                      0.235895
# 3161        Vilas County                      0.234365
# 3162     Walworth County                      0.249336
# 3163     Washburn County                      0.222385
# 3164   Washington County                      0.282530
# 3165     Waukesha County                      0.236117
# 3166      Waupaca County                      0.241507
# 3167     Waushara County                      0.232715
# 3168    Winnebago County                      0.255551
