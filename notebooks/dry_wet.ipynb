# %%
import pandas as pd
import matplotlib as plt

# %%
health_final = pd.read_csv('..\data\health_final.csv')

# %%
locations = pd.read_csv('..\data\location_df.csv', 
                       usecols=['id', 'name', 'streetAddress', 'locality', 'locationTypeDisplay',
                                'countryIsoCode', 'region', 'postalCode',
                                'latitude', 'longitude', 'brewery.isMassOwned'])

# %%
# Certain towns and cities are dry, so exceptions apply
dry_counties = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': ['Ashley County', 'Bradley County', 'Clay County', 'Cleburne County', 'Craighead County', 
               'Crawford County', 'Faulkner County', 'Fulton County', 'Grant County','Hempstead County', 
               'Hot Spring County', 'Howard County', 'Independence County', 'Izard County', 'Johnson County', 
               'Lafayette County', 'Lawrence County', 'Lincoln County', 'Little River County', 
               'Southern Logan County', 'Lonoke County', 'Madison County', 'Montgomery County', 
               'Newton County', 'Perry County', 'Pike County', 'Polk County', 'Pope County', 'Randolph County',
               'Scott County', 'Searcy County', 'Southern Sebastian County', 'Sevier County', 'Stone County',
               'Van Buren County', 'White County', 'Yell County'],
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': ['Lafayette County', 'Liberty County', 'Washington County'],
        'GA': ['Coweta County', 'Decatur County', 'Dodge County', 'Franklin County', 'Murray County'],
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': ['Jewell County', 'Sheridan County', 'Doniphan County', 'Clay County', 'Elk County', 'Rice County',
               'Stafford County', 'Gove County', 'Wallace County', 'Wichita County', 'Lane County', 'Gray County', 
               'Haskell County', 'Meade County', 'Clark County', 'Stevens County', 'Morton County', 'Stanton County',
               'Cherokee County'],
        'KY': ['Adair County', 'Allen County', 'Ballard County', 'Bath County', 'Breathitt County', 'Butler County', 
               'Carlisle County', 'Casey County', 'Clinton County', 'Crittenden County', 'Cumberland County', 
               'Elliott County', 'Estill County', 'Fleming County', 'Hancock County', 'Hart County', 'Hickman County',
               'Jackson County', 'Knott County', 'Knox County', 'Larue County', 'Lawrence County', 'Lee County', 
               'Leslie County', 'Lincoln County', 'McCreary County', 'McLean County', 'Martin County', 'Menifee County', 
               'Metcalfe County', 'Monroe County', 'Morgan County', 'Ohio County', 'Owsley County', 'Powell County', 
               'Robertson County', 'Rockcastle County', 'Russell County', 'Webster County'],
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': ['Tate County', 'Benton County', 'Tippah County', 'Tishomingo County', 'Prentiss County', 
               'Pontotoc County', 'Itawamba County', 'Calhoun County', 'Webster County', 'Choctaw County',
               'Smith County', 'Clarke County', 'Franklin County', 'Walthall County', 'Greene County',
               'George County'],
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'Oglala Lakota County',
        'SD': 'South Dakota',
        'TN': ['Benton County', 'Bledsoe County', 'Cannon County', 'Claiborne County', 'Crockett County',
               'Dekalb County', 'Fentress County', 'Grainger County', 'Hancock County', 'Hawkins County', 
               'Hickman County', 'Houston County', 'Jefferson County', 'Johnson County', 'Lake County', 
               'Macon County', 'McNairy County', 'Meigs County', 'Morgan County', 'Pickett County', 'Rhea County', 
               'Scott County', 'Stewart County', 'Union County'],
        'TX': ['Borden County', 'Collingsworth County', 'Hemphill County', 'Kent County', 'Martin County', 
               'Roberts County', 'Throckmorton County'],
        'US': 'United States',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
# Certain towns and cities are dry, so exceptions apply. Data from 2017. Outdated 
state_dry_counties = {
        'AR': ['Ashley County', 'Bradley County', 'Clay County', 'Cleburne County', 'Craighead County', 
               'Crawford County', 'Faulkner County', 'Fulton County', 'Grant County','Hempstead County', 
               'Hot Spring County', 'Howard County', 'Independence County', 'Izard County', 'Johnson County', 
               'Lafayette County', 'Lawrence County', 'Lincoln County', 'Little River County', 
               'Southern Logan County', 'Lonoke County', 'Madison County', 'Montgomery County', 
               'Newton County', 'Perry County', 'Pike County', 'Polk County', 'Pope County', 'Randolph County',
               'Scott County', 'Searcy County', 'Southern Sebastian County', 'Sevier County', 'Stone County',
               'Van Buren County', 'White County', 'Yell County'],
        'FL': ['Lafayette County', 'Liberty County', 'Washington County'],
        'GA': ['Coweta County', 'Decatur County', 'Dodge County', 'Franklin County', 'Murray County'],
        'KS': ['Jewell County', 'Sheridan County', 'Doniphan County', 'Clay County', 'Elk County', 'Rice County',
               'Stafford County', 'Gove County', 'Wallace County', 'Wichita County', 'Lane County', 'Gray County', 
               'Haskell County', 'Meade County', 'Clark County', 'Stevens County', 'Morton County', 'Stanton County',
               'Cherokee County'],
        'KY': ['Adair County', 'Allen County', 'Ballard County', 'Bath County', 'Breathitt County', 'Butler County', 
               'Carlisle County', 'Casey County', 'Clinton County', 'Crittenden County', 'Cumberland County', 
               'Elliott County', 'Estill County', 'Fleming County', 'Hancock County', 'Hart County', 'Hickman County',
               'Jackson County', 'Knott County', 'Knox County', 'Larue County', 'Lawrence County', 'Lee County', 
               'Leslie County', 'Lincoln County', 'McCreary County', 'McLean County', 'Martin County', 'Menifee County', 
               'Metcalfe County', 'Monroe County', 'Morgan County', 'Ohio County', 'Owsley County', 'Powell County', 
               'Robertson County', 'Rockcastle County', 'Russell County', 'Webster County'],
        'MS': ['Tate County', 'Benton County', 'Tippah County', 'Tishomingo County', 'Prentiss County', 
               'Pontotoc County', 'Itawamba County', 'Calhoun County', 'Webster County', 'Choctaw County',
               'Smith County', 'Clarke County', 'Franklin County', 'Walthall County', 'Greene County',
               'George County'],
        'SD': 'Oglala Lakota County',
        'TN': ['Benton County', 'Bledsoe County', 'Cannon County', 'Claiborne County', 'Crockett County',
               'Dekalb County', 'Fentress County', 'Grainger County', 'Hancock County', 'Hawkins County', 
               'Hickman County', 'Houston County', 'Jefferson County', 'Johnson County', 'Lake County', 
               'Macon County', 'McNairy County', 'Meigs County', 'Morgan County', 'Pickett County', 'Rhea County', 
               'Scott County', 'Stewart County', 'Union County'],
        'TX': ['Borden County', 'Collingsworth County', 'Hemphill County', 'Kent County', 'Martin County', 
               'Roberts County', 'Throckmorton County']
}

# %%
# def is_wet_county(county):
#     if county in wet_counties:
#         return 1
#     return 0

# %%
def is_wet_county(county):
    if county in dry_counties:
        return 1
    return 0

# %%
health_final['n'] = health_final['county'].map(state_dry_counties)

# %%
for k, v in dry_counties.items():
    if health_final.state_abbreviation in k:
        if health_final.county in v:
            return 1
        return 0
    continue
# Out:
#   File "<ipython-input-98-9983ffe5e8df>", line 4
#     return 1
#     ^
# SyntaxError: 'return' outside function

# %%
health_final
# Out:
#       state_fips_code  county_fips_code  5-digit_fips_code state_abbreviation  \
# 0                   0                 0                  0                 US
# 1                   1                 0               1000                 AL
# 2                   1                 1               1001                 AL
# 3                   1                 3               1003                 AL
# 4                   1                 5               1005                 AL
# ...               ...               ...                ...                ...
# 3189               56                37              56037                 WY
# 3190               56                39              56039                 WY
# 3191               56                41              56041                 WY
# 3192               56                43              56043                 WY
# 3193               56                45              56045                 WY
#
# ...

# %%
for i in health_final.county:
    print(i)
# Out:
# United States
# Alabama
# Autauga County
# Baldwin County
# Barbour County
# Bibb County
# Blount County
# Bullock County
# Butler County
# Calhoun County
# Chambers County
# Cherokee County
# Chilton County
# Choctaw County
# Clarke County
# Clay County
# Cleburne County
# Coffee County
# Colbert County
# Conecuh County
# Coosa County
# Covington County
# Crenshaw County
# Cullman County
# Dale County
# Dallas County
# DeKalb County
# Elmore County
# Escambia County
# Etowah County
# Fayette County
# Franklin County
# Geneva County
# Greene County
# Hale County
# Henry County
# Houston County
# Jackson County
# Jefferson County
# Lamar County
# Lauderdale County
# Lawrence County
# Lee County
# Limestone County
# Lowndes County
# Macon County
# Madison County
# Marengo County
# Marion County
# Marshall County
# Mobile County
# Monroe County
# Montgomery County
# Morgan County
# Perry County
# Pickens County
# Pike County
# Randolph County
# Russell County
# St. Clair County
# ...

# %%
# Certain towns and cities are dry, so exceptions apply. Data from 2017. Outdated 
['Ashley County', 'Bradley County', 'Clay County', 'Cleburne County', 'Craighead County', 
               'Crawford County', 'Faulkner County', 'Fulton County', 'Grant County','Hempstead County', 
               'Hot Spring County', 'Howard County', 'Independence County', 'Izard County', 'Johnson County', 
               'Lafayette County', 'Lawrence County', 'Lincoln County', 'Little River County', 
               'Southern Logan County', 'Lonoke County', 'Madison County', 'Montgomery County', 
               'Newton County', 'Perry County', 'Pike County', 'Polk County', 'Pope County', 'Randolph County',
               'Scott County', 'Searcy County', 'Southern Sebastian County', 'Sevier County', 'Stone County',
               'Van Buren County', 'White County', 'Yell County', 'Lafayette County', 'Liberty County', 'Washington County',
        'Coweta County', 'Decatur County', 'Dodge County', 'Franklin County', 'Murray County',
        'Jewell County', 'Sheridan County', 'Doniphan County', 'Clay County', 'Elk County', 'Rice County',
               'Stafford County', 'Gove County', 'Wallace County', 'Wichita County', 'Lane County', 'Gray County', 
               'Haskell County', 'Meade County', 'Clark County', 'Stevens County', 'Morton County', 'Stanton County',
               'Cherokee County',
        'Adair County', 'Allen County', 'Ballard County', 'Bath County', 'Breathitt County', 'Butler County', 
               'Carlisle County', 'Casey County', 'Clinton County', 'Crittenden County', 'Cumberland County', 
               'Elliott County', 'Estill County', 'Fleming County', 'Hancock County', 'Hart County', 'Hickman County',
               'Jackson County', 'Knott County', 'Knox County', 'Larue County', 'Lawrence County', 'Lee County', 
               'Leslie County', 'Lincoln County', 'McCreary County', 'McLean County', 'Martin County', 'Menifee County', 
               'Metcalfe County', 'Monroe County', 'Morgan County', 'Ohio County', 'Owsley County', 'Powell County', 
               'Robertson County', 'Rockcastle County', 'Russell County', 'Webster County',
        'Tate County', 'Benton County', 'Tippah County', 'Tishomingo County', 'Prentiss County', 
               'Pontotoc County', 'Itawamba County', 'Calhoun County', 'Webster County', 'Choctaw County',
               'Smith County', 'Clarke County', 'Franklin County', 'Walthall County', 'Greene County',
               'George County',
        'Oglala Lakota County',
        'Benton County', 'Bledsoe County', 'Cannon County', 'Claiborne County', 'Crockett County',
               'Dekalb County', 'Fentress County', 'Grainger County', 'Hancock County', 'Hawkins County', 
               'Hickman County', 'Houston County', 'Jefferson County', 'Johnson County', 'Lake County', 
               'Macon County', 'McNairy County', 'Meigs County', 'Morgan County', 'Pickett County', 'Rhea County', 
               'Scott County', 'Stewart County', 'Union County',
        'Borden County', 'Collingsworth County', 'Hemphill County', 'Kent County', 'Martin County', 
               'Roberts County', 'Throckmorton County']

# %%
def is_wet_county(county):
        if county in state_dry_counties.values():
            return 1
        return 0

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-39f17b0fdc5d> in <module>
# ----> 1 is_wet_county(health_final.county)
#
# <ipython-input-119-7c4286d55c43> in is_wet_county(county)
#       1 def is_wet_county(county):
#       2     for i in county:
# ----> 3         if county in state_dry_counties.values():
#       4             return 1
#       5         return 0
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
# ...

# %%
# Out:
# {'test': 3194}
